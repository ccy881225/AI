# %%
import googlemaps
import pandas as pd

gmaps = googlemaps.Client(key='AIzaSyCfhlXPia03ILdLMUpJyH9vjZKTJNX1oRk')

# %%
cities=["台中市西區民權路185號"]

# %%
ids=[ ]
for city in cities :
    geocode_result = gmaps.geocode(city)
    loc = geocode_result[0]['geometry']['location']
    print("以"+city+"為中心半徑1000公尺的餐廳店家數量: "+str(len(gmaps.places_nearby(keyword="餐廳",location=loc,radius=1000)['results'])))
    for place in gmaps.places_nearby(keyword="餐廳",location=loc,radius=1000)['results']:ids.append(place['place_id'])
# Out:
# 以台中市西區民權路185號為中心半徑1000公尺的餐廳店家數量: 20

# %%
stores_info = [ ]
ids = list(set(ids))
for id in ids:
    stores_info.append(gmaps.place(place_id=id, language='zh-TW')['result'])

# %%
output = pd.DataFrame.from_dict(stores_info)

# %%
output
# Out:
#                                    address_components  \
# 0   [{'long_name': '71號', 'short_name': '71號', 'ty...
# 1   [{'long_name': '177', 'short_name': '177', 'ty...
# 2   [{'long_name': '15號', 'short_name': '15號', 'ty...
# 3   [{'long_name': '249', 'short_name': '249', 'ty...
# 4   [{'long_name': '36號', 'short_name': '36號', 'ty...
# 5   [{'long_name': '109', 'short_name': '109', 'ty...
# 6   [{'long_name': '北区', 'short_name': '北区', 'type...
# 7   [{'long_name': '405號', 'short_name': '405號', '...
# 8   [{'long_name': '341號', 'short_name': '341號', '...
# 9   [{'long_name': '142號', 'short_name': '142號', '...
# 10  [{'long_name': '54號', 'short_name': '54號', 'ty...
# 11  [{'long_name': '55', 'short_name': '55', 'type...
# 12  [{'long_name': '379號', 'short_name': '379號', '...
# 13  [{'long_name': '276號', 'short_name': '276號', '...
# 14  [{'long_name': '155號', 'short_name': '155號', '...
# 15  [{'long_name': '86', 'short_name': '86', 'type...
# ...
